# %% [markdown]
# # Spark Introduction

# %%
from IPython.display import Image
#Image("img/picture.png")

# %% [raw]
# Hadoop Framework: HDFS, Mapreduce, MRV1, MRV2
#     Consists of two stages: Map and Reduce
#     Perfect for Batch jobs
#     Lot of IO is involved during the job execution and after the job is completed
#     Chain of Jobs ???? IO is the killer, can tolerate in Batch jobs but what about the real time processing    applications???

# %% [raw]
# Spark Framework:
#     It is a JVM based distributed data processing engine.
#     Originated at UC, Berkely
#     Runs applications much faster then Hadoop Mapreduce jobs
#     Does processing in the memory of the worker nodes.
#     Prevetns unnecessory IO operations
#     Provides ability to chain the tasks at application level
#     Minimizes number of writes to the Discs

# %% [raw]
# How Spark achives Efficiency??
#     Uses Directed Acyclic graph (DAG) processing engine
#     DAG of tasks are created for each Spark Job to be executed by the engine.
#     A DAG consists of set of vertices and connected directed Edges, Tasks are executed as per the DAG graph (While in  mapreduce job we have only two vertices- Map and Reduce)
#     In memory computation combining with DAG makes it very efficient for runnig Real time Jobs.

# %%
Image("img/Spark_DAG.png")

# %% [raw]
# Programming languages supported by Spark:
#     Scala
#     Python
#     Java
#     R
# Also Spark has Interective shells with REPL (Read, Evaluate, Print, Loop) capabilities in scala, python and R

# %% [markdown]
# # Spark Eco System:

# %%
Image("img/Spark_Eco_System.png")

# %% [raw]
# Spark Core:
#     Supports Basic Spark fuctionalities
#     RDD abstraction of data
#     Distributed data processing
#
# Spark SQL + Dataframes:
#     Enables to use SQL statements or Dataframe API in Spark applications
#     Scala, Java, Python, R
#
# Spark Streaming:
#     Enables processing of live data streams
#     Scala, Java, Python
#
# MLib:
#     Enables developement of Machine learning applications
#     Scala, Python, Java, R
#
# GraphX:
#     Enables graph processing and Graph algorithms
#     Scala

# %%
Image("img/Spark_Architecture.png")

# %% [raw]
# SparkContext object is the driver program.
# It communicates with the appropriate Cluster Manager.
# Driver program allocates tasks to the workers.
# SparkMaster (Part of Spark core lib), Mesos Master and Hadoop YARN Resource manager are examples of cluster managers supported by Spark.
